# %%
import ast
from transformers import AutoTokenizer, AutoModel
import torch
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd
import numpy as np

# %%
# Load a pre-trained model (e.g., Sentence-BERT)
tokenizer = AutoTokenizer.from_pretrained("sentence-transformers/all-MiniLM-L6-v2")
model = AutoModel.from_pretrained("sentence-transformers/all-MiniLM-L6-v2")

# %%
df = pd.read_csv('dataset/movies_all_data2.csv', encoding='utf-8')

df['genres'] = df['genres'].apply(ast.literal_eval)
# df['genres'] = df['genres'].apply(ast.literal_eval)
df['tags'] = df['tags'].apply(ast.literal_eval)
df['overview'] = df['overview'].apply(str)
df['characters'] = df['characters'].apply(ast.literal_eval)
df['directors'] = df['directors'].apply(ast.literal_eval)

# %%
def list_to_string(input_list):
    return ", ".join(input_list)

def preprocess(movie_data):
    return f"Title: {movie_data['title']}, Overview: {movie_data['overview']}, Genres: {list_to_string(movie_data['genres'])}, Tags: {list_to_string(movie_data['tags'])}, Directors: {list_to_string(movie_data['directors'])}, Characters: {list_to_string(movie_data['characters'])}"    

def encode_text(text):
    inputs = tokenizer(text, return_tensors="pt", padding=True, truncation=True)
    outputs = model(**inputs)
    embeddings = outputs.last_hidden_state.mean(dim=1).squeeze(0)   # Mean-pooling
    return embeddings.detach().numpy()

# Example: Create a corpus of combined text for all movies
# df['combined_text'] = df.apply(preprocess, axis=1)


# for index, row in df.iterrows():
#     print(f"Index: {index}, Name: {row['title']}, ID: {row['id']}")
#     print(df.columns)
#     preprocessed_text = preprocess(row)
#     print(preprocessed_text)

#     print(type(encode_text(preprocessed_text)))
#     # print(preprocess(row))

#     break

# %%
df['embeddings'] = df.apply(lambda x: encode_text(preprocess(x)), axis=1)

# %%
df["embeddings"][0].shape
# Out:
# (384,)

# %%
def get_similar_movies(df ,movie_id, n=5):
    movie_1 = df.loc[df['id'] == movie_id].squeeze()
    print(movie_1["title"], movie_1["genres"])
    query_embedding = movie_1['embeddings']
    # df2 = df
    # df2 = df[df['id'] != movie_id]
    all_embeddings = list(df['embeddings'])
    # all_embeddings = list(df['embeddings'])
    # all_embeddings = [
    #     embedding for id_, embedding in zip(df['id'], df['embeddings'])
    #     if id_ != movie_id
    # ]
    
    # Compute cosine similarity
    similarities = cosine_similarity([query_embedding], all_embeddings)
    
    # Get top-n similar movies
    similar_indices = similarities.argsort()[0][::-1][:(n+1)]
    return df.iloc[similar_indices][['id', 'title', 'genres', 'overview', 'tags', 'characters', 'directors', 'actors']]

# Example usage:

# %%
get_similar_movies(df, movie_id=49051, n=5)
# Out:
# The Hobbit: An Unexpected Journey ['Adventure', 'Fantasy', 'Action']
#            id                                              title  \
# 11753   49051                  The Hobbit: An Unexpected Journey
# 12723   57158                The Hobbit: The Desolation of Smaug
# 14121  122917          The Hobbit: The Battle of the Five Armies
# 3670      120  The Lord of the Rings: The Fellowship of the Ring
# 1523      123                              The Lord of the Rings
# 4321      121              The Lord of the Rings: The Two Towers
#
#                                        genres  \
# 11753            [Adventure, Fantasy, Action]
# 12723                    [Adventure, Fantasy]
# 14121            [Action, Adventure, Fantasy]
# 3670             [Adventure, Fantasy, Action]
# 1523   [Fantasy, Drama, Animation, Adventure]
# 4321             [Adventure, Fantasy, Action]
#
#                                                 overview  \
# 11753  Bilbo Baggins, a hobbit enjoying his quiet lif...
# 12723  The Dwarves, Bilbo and Gandalf have successful...
# 14121  Immediately after the events of The Desolation...
# 3670   Young hobbit Frodo Baggins, after inheriting a...
# 1523   The Fellowship of the Ring embark on a journey...
# 4321   Frodo and Sam are trekking to Mordor to destro...
#
#                                                     tags  \
# 11753  [riddle, elves, dwarves, orcs, middle-earth (t...
# 12723  [elves, dwarves, orcs, hobbit, dragon, wizard,...
# 14121  [corruption, elves, dwarves, orcs, middle-eart...
# 3670   [elves, dwarves, orcs, middle-earth (tolkien),...
# 1523                   [elves, dwarves, hobbit, mission]
# 4321   [elves, orcs, middle-earth (tolkien), hobbit, ...
#
#                                           characters  \
# 11753                       [Gandalf, Bilbo, Thorin]
# 12723   [Bilbo Baggins, Gandalf, Thorin Oakenshield]
# 14121   [Bilbo Baggins, Gandalf, Thorin Oakenshield]
# 3670    [Frodo Baggins, Gandalf the Grey, Galadriel]
# 1523   [Frodo (voice), Gandalf (voice), Sam (voice)]
# 4321     [Frodo Baggins, Gandalf the White, Aragorn]
#
#                                                directors  \
# 11753                 [Peter Jackson, Victoria Sullivan]
# 12723  [Peter Jackson, Carolynne Cunningham, Veroniqu...
# 14121                                    [Peter Jackson]
# 3670                                     [Peter Jackson]
# 1523                                      [Ralph Bakshi]
# 4321                                     [Peter Jackson]
#
#                                                   actors
# 11753  ['Ian McKellen', 'Martin Freeman', 'Richard Ar...
# 12723  ['Martin Freeman', 'Ian McKellen', 'Richard Ar...
# 14121  ['Martin Freeman', 'Ian McKellen', 'Richard Ar...
# 3670   ['Elijah Wood', 'Ian McKellen', 'Cate Blanchett']
# 1523   ['Christopher Guard', 'William Squire', 'Micha...
# 4321   ['Elijah Wood', 'Ian McKellen', 'Viggo Mortens...

# %%
get_similar_movies(df, movie_id=68721, n=5)
# Out:
# Iron Man 3 ['Action', 'Adventure', 'Science Fiction']
#            id                         title  \
# 12110   68721                    Iron Man 3
# 8392     1726                      Iron Man
# 9656    10138                    Iron Man 2
# 12094  169934  Iron Man: Rise of Technovore
# 10825   24428                  The Avengers
# 12088   13647       The Invincible Iron Man
#
#                                      genres  \
# 12110  [Action, Adventure, Science Fiction]
# 8392   [Action, Science Fiction, Adventure]
# 9656   [Adventure, Action, Science Fiction]
# 12094  [Science Fiction, Animation, Action]
# 10825  [Science Fiction, Action, Adventure]
# 12088  [Animation, Action, Science Fiction]
#
#                                                 overview  \
# 12110  When Tony Stark's world is torn apart by a for...
# 8392   After being held captive in an Afghan cave, bi...
# 9656   With the world now aware of his dual life as t...
# 12094  Iron Man enlists the help of ruthless vigilant...
# 10825  When an unexpected enemy emerges and threatens...
# 12088  When a cocky industrialist's efforts to raise ...
#
#                                                     tags  \
# 12110  [terrorist, war on terror, tennessee, malibu, ...
# 8392   [middle east, arms dealer, malibu, marvel comi...
# 9656   [malibu, marvel comic, superhero, based on com...
# 12094  [marvel comic, superhero, based on comic, mech...
# 10825  [new york, shield, marvel comic, superhero, ba...
# 12088  [prophecy, armor, marvel comic, billionaire, b...
#
#                                               characters  \
# 12110  [Tony Stark / Iron Man, Virginia "Pepper" Pott...
# 8392   [Tony Stark / Iron Man, Lt. Col. James "Rhodey...
# 9656   [Tony Stark / Iron Man, Virginia "Pepper" Pott...
# 12094  [Frank Castle / The Punisher (voice), Tony Sta...
# 10825  [Tony Stark / Iron Man, Steve Rogers / Captain...
# 12088        [Tony Stark Iron Man, Li Mei, Howard Stark]
#
#                                                directors  \
# 12110                                      [Shane Black]
# 8392                    [Jon Favreau, Cristina Weigmann]
# 9656                                       [Jon Favreau]
# 12094  [Hiroshi Hamazaki, Kenichi Kawamura, Shingo Na...
# 10825                       [Joss Whedon, Trudy Ramirez]
# 12088                     [Jay Oliva, Patrick Archibald]
#
#                                                   actors
# 12110  ['Robert Downey Jr.', 'Gwyneth Paltrow', 'Don ...
# 8392   ['Robert Downey Jr.', 'Terrence Howard', 'Jeff...
# 9656   ['Robert Downey Jr.', 'Gwyneth Paltrow', 'Don ...
# 12094  ['Tesshou Genda', 'Keiji Fujiwara', 'Miyu Irino']
# 10825  ['Robert Downey Jr.', 'Chris Evans', 'Mark Ruf...
# 12088   ['Marc Worden', 'Gwendoline Yeo', 'John McCook']

# %%
get_similar_movies(df, movie_id=49051, n=5)
# Out:
# The Hobbit: An Unexpected Journey ['Adventure', 'Fantasy', 'Action']
#            id                                              title  \
# 11753   49051                  The Hobbit: An Unexpected Journey
# 12723   57158                The Hobbit: The Desolation of Smaug
# 14121  122917          The Hobbit: The Battle of the Five Armies
# 3670      120  The Lord of the Rings: The Fellowship of the Ring
# 1523      123                              The Lord of the Rings
# 4321      121              The Lord of the Rings: The Two Towers
#
#                                        genres  \
# 11753            [Adventure, Fantasy, Action]
# 12723                    [Adventure, Fantasy]
# 14121            [Action, Adventure, Fantasy]
# 3670             [Adventure, Fantasy, Action]
# 1523   [Fantasy, Drama, Animation, Adventure]
# 4321             [Adventure, Fantasy, Action]
#
#                                                 overview  \
# 11753  Bilbo Baggins, a hobbit enjoying his quiet lif...
# 12723  The Dwarves, Bilbo and Gandalf have successful...
# 14121  Immediately after the events of The Desolation...
# 3670   Young hobbit Frodo Baggins, after inheriting a...
# 1523   The Fellowship of the Ring embark on a journey...
# 4321   Frodo and Sam are trekking to Mordor to destro...
#
#                                                     tags  \
# 11753  [riddle, elves, dwarves, orcs, middle-earth (t...
# 12723  [elves, dwarves, orcs, hobbit, dragon, wizard,...
# 14121  [corruption, elves, dwarves, orcs, middle-eart...
# 3670   [elves, dwarves, orcs, middle-earth (tolkien),...
# 1523                   [elves, dwarves, hobbit, mission]
# 4321   [elves, orcs, middle-earth (tolkien), hobbit, ...
#
#                                           characters  \
# 11753                       [Gandalf, Bilbo, Thorin]
# 12723   [Bilbo Baggins, Gandalf, Thorin Oakenshield]
# 14121   [Bilbo Baggins, Gandalf, Thorin Oakenshield]
# 3670    [Frodo Baggins, Gandalf the Grey, Galadriel]
# 1523   [Frodo (voice), Gandalf (voice), Sam (voice)]
# 4321     [Frodo Baggins, Gandalf the White, Aragorn]
#
#                                                directors  \
# 11753                 [Peter Jackson, Victoria Sullivan]
# 12723  [Peter Jackson, Carolynne Cunningham, Veroniqu...
# 14121                                    [Peter Jackson]
# 3670                                     [Peter Jackson]
# 1523                                      [Ralph Bakshi]
# 4321                                     [Peter Jackson]
#
#                                                   actors
# 11753  ['Ian McKellen', 'Martin Freeman', 'Richard Ar...
# 12723  ['Martin Freeman', 'Ian McKellen', 'Richard Ar...
# 14121  ['Martin Freeman', 'Ian McKellen', 'Richard Ar...
# 3670   ['Elijah Wood', 'Ian McKellen', 'Cate Blanchett']
# 1523   ['Christopher Guard', 'William Squire', 'Micha...
# 4321   ['Elijah Wood', 'Ian McKellen', 'Viggo Mortens...

# %%
get_similar_movies(df, movie_id=155, n=5)
# Out:
# The Dark Knight ['Drama', 'Action', 'Crime', 'Thriller']
#            id                                    title  \
# 8335      155                          The Dark Knight
# 11013   49026                    The Dark Knight Rises
# 451       268                                   Batman
# 6984      272                            Batman Begins
# 11691  123025  Batman: The Dark Knight Returns, Part 1
# 8534    13851                    Batman: Gotham Knight
#
#                                  genres  \
# 8335   [Drama, Action, Crime, Thriller]
# 11013  [Action, Crime, Drama, Thriller]
# 451                   [Fantasy, Action]
# 6984             [Action, Crime, Drama]
# 11691               [Action, Animation]
# 8534     [Animation, Action, Adventure]
#
#                                                 overview  \
# 8335   Batman raises the stakes in his war on crime. ...
# 11013  Following the death of District Attorney Harve...
# 451    The Dark Knight of Gotham City begins his war ...
# 6984   Driven by tragedy, billionaire Bruce Wayne ded...
# 11691  Batman has not been seen for ten years. A new ...
# 8534   Explore Bruce Wayne's transition from his begi...
#
#                                                     tags  \
# 8335   [dc comics, crime fighter, secret identity, sc...
# 11013  [dc comics, crime fighter, terrorist, secret i...
# 451    [double life, dc comics, dual identity, chemic...
# 6984   [himalaya, martial arts, dc comics, crime figh...
# 11691  [dc comics, future, based on graphic novel, dy...
# 8534                [dc comics, anthology, super powers]
#
#                                               characters  \
# 8335    [Bruce Wayne / Batman, Alfred Pennyworth, Joker]
# 11013  [Bruce Wayne / Batman, Alfred Pennyworth, Jame...
# 451    [Jack Napier/The Joker, Bruce Wayne/Batman, Vi...
# 6984   [Bruce Wayne / Batman, Alfred Pennyworth, Henr...
# 11691  [Batman / Bruce Wayne, Robin / Carrie Kelley, ...
# 8534   [Batman / Bruce Wayne (voice), Crispus Allen (...
#
#                                                directors  \
# 8335       [Christopher Nolan, Steve Gehrke, Nilo Otero]
# 11013  [Christopher Nolan, Steve Gehrke, Matthew Reed...
# 451                                         [Tim Burton]
# 6984      [Christopher Nolan, Annie Penn, Cliff Lanning]
# 11691                                        [Jay Oliva]
# 8534   [Yasuhiro Aoki, Hiroshi Morioka, Jong-Sik Nam,...
#
#                                                   actors
# 8335   ['Christian Bale', 'Michael Caine', 'Heath Led...
# 11013  ['Christian Bale', 'Michael Caine', 'Gary Oldm...
# 451    ['Jack Nicholson', 'Michael Keaton', 'Kim Basi...
# 6984   ['Christian Bale', 'Michael Caine', 'Liam Nees...
# 11691    ['Peter Weller', 'Ariel Winter', 'David Selby']
# 8534   ['Kevin Conroy', 'Gary Dourdan', 'Jason Marsden']

# %%
df.sort_values(by='vote_count', ascending=False).head(20)
# Out:
#        adult      id original_language  \
# 9800   False   27205                en
# 8335   False     155                en
# 9364   False   19995                en
# 10825  False   24428                en
# 14611  False  293660                en
# 13039  False  157336                en
# 11778  False   68718                en
# 13444  False  118340                en
# 2192   False     550                en
# 11011  False   70160                en
# 14603  False   76341                en
# 11013  False   49026                en
# 1892   False     603                en
# 12110  False   68721                en
# 8392   False    1726                en
# 3670   False     120                en
# 14003  False  135397                en
# 234    False     680                en
# 11753  False   49051                en
# 246    False     278                en
#
#                                           original_title  \
# 9800                                           Inception
# 8335                                     The Dark Knight
# 9364                                              Avatar
# 10825                                       The Avengers
# 14611                                           Deadpool
# 13039                                       Interstellar
# 11778                                   Django Unchained
# 13444                            Guardians of the Galaxy
# 2192                                          Fight Club
# 11011                                   The Hunger Games
# 14603                                 Mad Max: Fury Road
# 11013                              The Dark Knight Rises
# 1892                                          The Matrix
# 12110                                         Iron Man 3
# 8392                                            Iron Man
# 3670   The Lord of the Rings: The Fellowship of the Ring
# 14003                                     Jurassic World
# 234                                         Pulp Fiction
# 11753                  The Hobbit: An Unexpected Journey
# 246                             The Shawshank Redemption
#
#                                                 overview  popularity  runtime  \
# 9800   Cobb, a skilled thief who commits corporate es...   29.108149    148.0
# 8335   Batman raises the stakes in his war on crime. ...  123.167259    152.0
# 9364   In the 22nd century, a paraplegic Marine is di...  185.070892    162.0
# 10825  When an unexpected enemy emerges and threatens...   89.887648    143.0
# 14611  Deadpool tells the origin story of former Spec...  187.860492    108.0
# 13039  Interstellar chronicles the adventures of a gr...   32.213481    169.0
# 11778  With the help of a German bounty hunter, a fre...   19.785025    165.0
# 13444  Light years from Earth, 26 years after being a...   53.291601    121.0
# 2192   A ticking-time-bomb insomniac and a slippery s...   63.869599    139.0
# 11011  Every year in the ruins of what was once North...   20.031667    142.0
# 14603  An apocalyptic story set in the furthest reach...   29.361780    120.0
# 11013  Following the death of District Attorney Harve...   20.582580    165.0
# 1892   Set in the 22nd century, The Matrix tells the ...   33.366332    136.0
# 12110  When Tony Stark's world is torn apart by a for...   23.721243    130.0
# 8392   After being held captive in an Afghan cave, bi...   22.073099    126.0
# 3670   Young hobbit Frodo Baggins, after inheriting a...   32.070725    178.0
# 14003  Twenty-two years after the events of Jurassic ...   32.790475    124.0
# 234    A burger-loving hit man, his philosophical par...  140.950236    154.0
# 11753  Bilbo Baggins, a hobbit enjoying his quiet lif...   23.253089    169.0
# 246    Framed in the 1940s for the double murder of h...   51.645403    142.0
#
#                                                  tagline  \
# 9800                Your mind is the scene of the crime.
# 8335                                     Why So Serious?
# 9364                         Enter the World of Pandora.
# 10825                            Some assembly required.
# 14611            Witness the beginning of a happy ending
# 13039  Mankind was born on Earth. It was never meant ...
# 11778        Life, liberty and the pursuit of vengeance.
# 13444                        All heroes start somewhere.
# 2192                             Mischief. Mayhem. Soap.
# 11011                May The Odds Be Ever In Your Favor.
# 14603                                 What a Lovely Day.
# 11013                                    The Legend Ends
# 1892                          Welcome to the Real World.
# 12110                Unleash the power behind the armor.
# 8392                  Heroes aren't born. They're built.
# 3670                           One ring to rule them all
# 14003                                  The park is open.
# 234    Just because you are a character doesn't mean ...
# 11753  From the smallest beginnings come the greatest...
# 246    Fear can hold you prisoner. Hope can set you f...
#
#                                                    title  vote_average  \
# 9800                                           Inception           8.1
# 8335                                     The Dark Knight           8.3
# 9364                                              Avatar           7.2
# 10825                                       The Avengers           7.4
# 14611                                           Deadpool           7.4
# 13039                                       Interstellar           8.1
# 11778                                   Django Unchained           7.8
# 13444                            Guardians of the Galaxy           7.9
# 2192                                          Fight Club           8.3
# 11011                                   The Hunger Games           6.9
# 14603                                 Mad Max: Fury Road           7.3
# 11013                              The Dark Knight Rises           7.6
# 1892                                          The Matrix           7.9
# 12110                                         Iron Man 3           6.8
# 8392                                            Iron Man           7.4
# 3670   The Lord of the Rings: The Fellowship of the Ring           8.0
# 14003                                     Jurassic World           6.5
# 234                                         Pulp Fiction           8.3
# 11753                  The Hobbit: An Unexpected Journey           7.0
# 246                             The Shawshank Redemption           8.5
#
#        vote_count                                             genres  \
# 9800      14075.0  [Action, Thriller, Science Fiction, Mystery, A...
# 8335      12269.0                   [Drama, Action, Crime, Thriller]
# 9364      12114.0      [Action, Adventure, Fantasy, Science Fiction]
# 10825     12000.0               [Science Fiction, Action, Adventure]
# 14611     11444.0                        [Action, Adventure, Comedy]
# 13039     11187.0                [Adventure, Drama, Science Fiction]
# 11778     10297.0                                   [Drama, Western]
# 13444     10014.0               [Action, Science Fiction, Adventure]
# 2192       9678.0                                            [Drama]
# 11011      9634.0              [Science Fiction, Adventure, Fantasy]
# 14603      9629.0     [Action, Adventure, Science Fiction, Thriller]
# 11013      9263.0                   [Action, Crime, Drama, Thriller]
# 1892       9079.0                          [Action, Science Fiction]
# 12110      8951.0               [Action, Adventure, Science Fiction]
# 8392       8951.0               [Action, Science Fiction, Adventure]
# 3670       8892.0                       [Adventure, Fantasy, Action]
# 14003      8842.0     [Action, Adventure, Science Fiction, Thriller]
# 234        8670.0                                  [Thriller, Crime]
# 11753      8427.0                       [Adventure, Fantasy, Action]
# 246        8358.0                                     [Drama, Crime]
#
#        release_year                                  overview_keywords  \
# 9800         2010.0  ['cobb', 'skilled', 'thief', 'commit', 'corpor...
# 8335         2008.0  ['batman', 'raise', 'stake', 'war', 'crime', '...
# 9364         2009.0  ['nd', 'century', 'paraplegic', 'marine', 'dis...
# 10825        2012.0  ['unexpected', 'enemy', 'emerge', 'threaten', ...
# 14611        2016.0  ['deadpool', 'tell', 'origin', 'story', 'speci...
# 13039        2014.0  ['interstellar', 'chronicle', 'adventure', 'gr...
# 11778        2012.0  ['help', 'german', 'bounty', 'hunter', 'freed'...
# 13444        2014.0  ['light', 'year', 'earth', 'year', 'abduct', '...
# 2192         1999.0  ['tickingtimebomb', 'insomniac', 'slippery', '...
# 11011        2012.0  ['year', 'ruin', 'north', 'america', 'nation',...
# 14603        2015.0  ['apocalyptic', 'story', 'set', 'furth', 'reac...
# 11013        2012.0  ['follow', 'death', 'district', 'attorney', 'h...
# 1892         1999.0  ['set', 'nd', 'century', 'matrix', 'tell', 'st...
# 12110        2013.0  ['tony', 'stark', 'world', 'tear', 'apart', 'f...
# 8392         2008.0  ['hold', 'captive', 'afghan', 'cave', 'billion...
# 3670         2001.0  ['young', 'hobbit', 'frodo', 'baggin', 'inheri...
# 14003        2015.0  ['twentytwo', 'year', 'event', 'jurassic', 'pa...
# 234          1994.0  ['burgerlove', 'hit', 'man', 'philosophical', ...
# 11753        2012.0  ['bilbo', 'baggin', 'hobbit', 'enjoy', 'quiet'...
# 246          1994.0  ['frame', 'double', 'murder', 'wife', 'lover',...
#
#                                                     tags  \
# 9800   [loss of lover, dream, kidnapping, sleep, subc...
# 8335   [dc comics, crime fighter, secret identity, sc...
# 9364   [culture clash, future, space war, space colon...
# 10825  [new york, shield, marvel comic, superhero, ba...
# 14611  [anti hero, mercenary, marvel comic, superhero...
# 13039  [saving the world, artificial intelligence, fa...
# 11778  [bounty hunter, hero, plantation, society, fri...
# 13444  [marvel comic, spaceship, space, outer space, ...
# 2192   [support group, dual identity, nihilism, rage ...
# 11011  [hallucination, dystopia, female protagonist, ...
# 14603  [future, chase, post-apocalyptic, dystopia, au...
# 11013  [dc comics, crime fighter, terrorist, secret i...
# 1892   [saving the world, artificial intelligence, ma...
# 12110  [terrorist, war on terror, tennessee, malibu, ...
# 8392   [middle east, arms dealer, malibu, marvel comi...
# 3670   [elves, dwarves, orcs, middle-earth (tolkien),...
# 14003  [monster, dna, tyrannosaurus rex, velociraptor...
# 234    [transporter, brothel, drug dealer, boxer, mas...
# 11753  [riddle, elves, dwarves, orcs, middle-earth (t...
# 246    [prison, corruption, police brutality, prison ...
#
#                                                directors  \
# 9800                                 [Christopher Nolan]
# 8335       [Christopher Nolan, Steve Gehrke, Nilo Otero]
# 9364                                     [James Cameron]
# 10825                       [Joss Whedon, Trudy Ramirez]
# 14611                                       [Tim Miller]
# 13039                                [Christopher Nolan]
# 11778  [Quentin Tarantino, Martin Kitrosser, William ...
# 13444                                       [James Gunn]
# 2192                        [David Fincher, Dina Waxman]
# 11011                          [Gary Ross, Dawn Gilliam]
# 14603  [George Miller, P.J. Voeten, Sophie Fabbri-Jac...
# 11013  [Christopher Nolan, Steve Gehrke, Matthew Reed...
# 1892   [Lana Wachowski, Lilly Wachowski, Victoria Sul...
# 12110                                      [Shane Black]
# 8392                    [Jon Favreau, Cristina Weigmann]
# 3670                                     [Peter Jackson]
# 14003  [Colin Trevorrow, Chris Castaldi, Scott Koche,...
# 234    [Quentin Tarantino, Francis R. Mahony III, Mar...
# 11753                 [Peter Jackson, Victoria Sullivan]
# 246    [Frank Darabont, John R. Woodward, Thomas Sche...
#
#                                               characters  \
# 9800                         [Dom Cobb, Arthur, Ariadne]
# 8335    [Bruce Wayne / Batman, Alfred Pennyworth, Joker]
# 9364   [Jake Sully, Princess Neytiri, Dr. Grace Augus...
# 10825  [Tony Stark / Iron Man, Steve Rogers / Captain...
# 14611  [Wade Wilson / Deadpool, Vanessa Carlysle / Co...
# 13039    [Joseph Cooper, Murph Cooper, Dr. Amelia Brand]
# 11778          [Django, Dr. King Schultz, Calvin Candie]
# 13444  [Peter Quill / Star-Lord, Gamora, Drax the Des...
# 2192   [The Narrator, Tyler Durden, Robert 'Bob' Paul...
# 11011  [Katniss Everdeen, Peeta Mellark, Gale Hawthorne]
# 14603          [Max Rockatansky, Imperator Furiosa, Nux]
# 11013  [Bruce Wayne / Batman, Alfred Pennyworth, Jame...
# 1892          [Thomas "Neo" Anderson, Morpheus, Trinity]
# 12110  [Tony Stark / Iron Man, Virginia "Pepper" Pott...
# 8392   [Tony Stark / Iron Man, Lt. Col. James "Rhodey...
# 3670        [Frodo Baggins, Gandalf the Grey, Galadriel]
# 14003        [Owen Grady, Claire Dearing, Simon Masrani]
# 234          [Vincent Vega, Jules Winfield, Mia Wallace]
# 11753                           [Gandalf, Bilbo, Thorin]
# 246    [Andy Dufresne, Ellis Boyd 'Red' Redding, Ward...
#
#                                                   actors  \
# 9800   ['Leonardo DiCaprio', 'Joseph Gordon-Levitt', ...
# 8335   ['Christian Bale', 'Michael Caine', 'Heath Led...
# 9364   ['Sam Worthington', 'Zoe Saldana', 'Sigourney ...
# 10825  ['Robert Downey Jr.', 'Chris Evans', 'Mark Ruf...
# 14611  ['Ryan Reynolds', 'Morena Baccarin', 'Ed Skrein']
# 13039  ['Matthew McConaughey', 'Jessica Chastain', 'A...
# 11778  ['Jamie Foxx', 'Christoph Waltz', 'Leonardo Di...
# 13444    ['Chris Pratt', 'Zoe Saldana', 'Dave Bautista']
# 2192         ['Edward Norton', 'Brad Pitt', 'Meat Loaf']
# 11011  ['Jennifer Lawrence', 'Josh Hutcherson', 'Liam...
# 14603  ['Tom Hardy', 'Charlize Theron', 'Nicholas Hou...
# 11013  ['Christian Bale', 'Michael Caine', 'Gary Oldm...
# 1892   ['Keanu Reeves', 'Laurence Fishburne', 'Carrie...
# 12110  ['Robert Downey Jr.', 'Gwyneth Paltrow', 'Don ...
# 8392   ['Robert Downey Jr.', 'Terrence Howard', 'Jeff...
# 3670   ['Elijah Wood', 'Ian McKellen', 'Cate Blanchett']
# 14003  ['Chris Pratt', 'Bryce Dallas Howard', 'Irrfan...
# 234    ['John Travolta', 'Samuel L. Jackson', 'Uma Th...
# 11753  ['Ian McKellen', 'Martin Freeman', 'Richard Ar...
# 246      ['Tim Robbins', 'Morgan Freeman', 'Bob Gunton']
#
#                                               embeddings
# 9800   [-0.14670397, 0.08696344, -0.09322027, -0.0624...
# 8335   [-0.008470067, -0.07082076, -0.21791284, -0.09...
# 9364   [-0.015838021, 0.006896694, 0.088935144, -0.14...
# 10825  [-0.11675756, -0.0029766196, -0.070140295, -0....
# 14611  [-0.12071296, -0.086758055, -0.10347109, -0.02...
# 13039  [-0.1349882, -0.18524994, 0.06554142, 0.077785...
# 11778  [-0.14034198, -0.00047503712, -0.12317582, 0.0...
# 13444  [-0.15897991, 0.03049575, 0.14649367, -0.11911...
# 2192   [-0.12449401, -0.10854275, -0.15160537, -0.014...
# 11011  [0.06546191, 0.010160887, 0.051277403, -0.1979...
# 14603  [-0.039949514, -0.23043123, -0.0579374, 0.0043...
# 11013  [-0.027050203, -0.094280355, -0.17933764, -0.0...
# 1892   [-0.05520811, -0.0026228463, -0.3285594, -0.14...
# 12110  [-0.12394958, -0.15541849, -0.13010198, 0.0141...
# 8392   [-0.10670321, 0.10779237, -0.10066733, 0.01479...
# 3670   [-0.06798298, 0.011018719, -0.11268659, -0.103...
# 14003  [-0.03808122, -0.11803438, 0.061548825, -0.091...
# 234    [-0.061548606, -0.13194284, -0.11159338, 0.046...
# 11753  [-0.09427071, 0.09226973, 0.008005374, -0.0702...
# 246    [-0.06641111, -0.16056441, -0.1703054, -0.0142...
